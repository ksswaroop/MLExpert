# %%
import os
from getpass import getpass

# Set API keys
#os.environ['OPENAI_API_KEY'] = getpass("Enter OpenAI Key")
#os.environ["LANGCHAIN_API_KEY"] = getpass("Enter Langchain API Key")

# Langsmith Tracking
#os.environ["LANGCHAIN_PROJECT"] = getpass("LANGCHAIN_PROJECT")
#os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
#os.environ["LANGCHAIN_TRACING_V2"] = "true"  # Correctly setting the tracing variable
os.environ["HF_TOKEN"]=getpass("Enter HuggingFace token")
# Out:
# Enter HuggingFace token ········

# %%
from transformers import AutoTokenizer
MODEL_NAME="meta-llama/Meta-Llama-3.1-8B-Instruct"
tokenizer=AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_errors.py:286, in hf_raise_for_status(response, endpoint_name)
#     285 try:
# --> 286     response.raise_for_status()
#     287 except HTTPError as e:
#
# File /usr/local/lib/python3.11/dist-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...
